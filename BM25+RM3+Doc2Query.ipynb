# %%
# Run BM25 + RM3 (with default parameters) on 200 TREC queries with doc2query index
import os
get_ipython().system = os.system

# !target/appassembler/bin/SearchCollection \
  -index indexes/msmarco-passage/lucene-index-msmarco-expanded-topk10 \
  -topics collections/msmarco-passage/queries.200.tsv \
  -topicreader TsvInt \
  -output runs/run.msmarco-passage.bm25-default+d2q+rm3.topics.msmarco-passage.200.txt \
  -bm25 -rm3 &
# Out:
# 0
# 2022-03-05 12:21:40,074 INFO  [main] search.SearchCollection (SearchCollection.java:378) - ============ Initializing Searcher ============
# 2022-03-05 12:21:40,076 INFO  [main] search.SearchCollection (SearchCollection.java:379) - Index: indexes/msmarco-passage/lucene-index-msmarco-expanded-topk10
# 2022-03-05 12:21:40,249 INFO  [main] search.SearchCollection (SearchCollection.java:459) - Language: en
# 2022-03-05 12:21:40,249 INFO  [main] search.SearchCollection (SearchCollection.java:460) - Stemmer: porter
# 2022-03-05 12:21:40,250 INFO  [main] search.SearchCollection (SearchCollection.java:461) - Keep stopwords? false
# 2022-03-05 12:21:40,250 INFO  [main] search.SearchCollection (SearchCollection.java:462) - Stopwords file: null
# 2022-03-05 12:21:40,251 INFO  [main] search.SearchCollection (SearchCollection.java:463) - Number of threads for running different parameter configurations: 1
# ...

# %%
# NDCG (from trec_eval) for different ranks, rank 10 (second line) is used in our report
# !tools/eval/trec_eval.9.0.4/trec_eval -c -mndcg_cut collections/msmarco-passage/2019qrels-pass.txt runs/run.msmarco-passage.bm25-default+d2q+rm3.topics.msmarco-passage.200.txt
# Out:
# ndcg_cut_5            	all	0.5535
# ndcg_cut_10           	all	0.5640
# ndcg_cut_15           	all	0.5493
# ndcg_cut_20           	all	0.5382
# ndcg_cut_30           	all	0.5344
# ndcg_cut_100          	all	0.5502
# ndcg_cut_200          	all	0.5805
# ndcg_cut_500          	all	0.6265
# ndcg_cut_1000         	all	0.6529
# 0

# %%
# Run BM25 + RM3 (with default parameters) on 500 train queries with doc2query index
# !target/appassembler/bin/SearchCollection \
  -index indexes/msmarco-passage/lucene-index-msmarco-expanded-topk10 \
  -topics collections/msmarco-passage/queries.train.500.tsv \
  -topicreader TsvInt \
  -output runs/run.msmarco-passage.bm25-default+d2q+rm3.topics.msmarco-passage.500.tsv -format msmarco \
  -bm25 -rm3 &
# Out:
# 0
# 2022-03-05 14:23:03,286 INFO  [main] search.SearchCollection (SearchCollection.java:378) - ============ Initializing Searcher ============
# 2022-03-05 14:23:03,288 INFO  [main] search.SearchCollection (SearchCollection.java:379) - Index: indexes/msmarco-passage/lucene-index-msmarco-expanded-topk10
# 2022-03-05 14:23:03,485 INFO  [main] search.SearchCollection (SearchCollection.java:459) - Language: en
# 2022-03-05 14:23:03,485 INFO  [main] search.SearchCollection (SearchCollection.java:460) - Stemmer: porter
# 2022-03-05 14:23:03,486 INFO  [main] search.SearchCollection (SearchCollection.java:461) - Keep stopwords? false
# 2022-03-05 14:23:03,486 INFO  [main] search.SearchCollection (SearchCollection.java:462) - Stopwords file: null
# 2022-03-05 14:23:03,487 INFO  [main] search.SearchCollection (SearchCollection.java:463) - Number of threads for running different parameter configurations: 1
# ...

# %%
# MRR at rank 10 for all 500 training queries (using original msmarco_passage_eval file)
# !python tools/scripts/msmarco/msmarco_passage_eval.py \
 collections/msmarco-passage/qrels.train.tsv runs/run.msmarco-passage.bm25-default+d2q+rm3.topics.msmarco-passage.500.tsv
# Out:
# Queries Ranked: 500
# #####################
# MRR @10: 0.2008968253968255
# QueriesRanked: 500
# #####################
# 0

# %%
# RR at rank 100 for each 500 training queries (using our modified msmarco_passage_eval_modified file)
# !python tools/scripts/msmarco/msmarco_passage_eval_modified.py \
 collections/msmarco-passage/qrels.train.tsv runs/run.msmarco-passage.bm25-default+d2q+rm3.topics.msmarco-passage.500.tsv
# Out:
# 2341 0
# 4801 0.2
# 6621 0.09090909090909091
# 9024 0.3333333333333333
# 10656 1.0
# 12527 0
# 16151 0.5
# 20627 0.25
# 20660 0.25
# 22774 0.25
# 23229 0.01818181818181818
# 23260 1.0
# 23949 0.3333333333333333
# 24876 0.5
# 29939 0.03125
# 33067 1.0
# 34189 0.25
# 36435 0
# 39302 0.16666666666666666
# 39431 0.25
# 40039 0.25
# 40105 1.0
# 40436 0.011904761904761904
# 45248 0.02857142857142857
# 48934 0.25
# 49519 0
# 50919 0.5
# 53141 0.025
# 54528 0.08333333333333333
# 57187 0.2
# 59236 0.5
# 61334 0.16666666666666666
# 64798 0
# 65428 0.5
# 65739 0
# 66378 0.14285714285714285
# 68636 0.08333333333333333
# 69522 0.08333333333333333
# 80926 0
# 81122 0
# 82881 0
# 86112 0.03225806451612903
# 87223 0.125
# 89631 1.0
# 91415 0.25
# 100924 0.3333333333333333
# 101053 0.2
# 103514 0.125
# 107646 1.0
# 115802 0.013513513513513514
# 120301 0.017241379310344827
# 120533 0
# 121352 0.2
# 121755 0.024390243902439025
# 122479 0.5
# 122753 0.043478260869565216
# 123192 0.010638297872340425
# ...

# %%
# Run BM25 + RM3 (with default parameters) on 500 developer queries 
import os
get_ipython().system = os.system

# !target/appassembler/bin/SearchCollection \
  -index indexes/msmarco-passage/lucene-index-msmarco-expanded-topk10 \
  -topics collections/msmarco-passage/queries.dev.500.tsv \
  -topicreader TsvInt \
  -output runs/run.msmarco-passage.bm25-default+d2q+rm3.topics.msmarco-passage.dev.500.tsv -format msmarco \
  -bm25 -rm3 &
# Out:
# 0
# 2022-03-06 12:31:35,512 INFO  [main] search.SearchCollection (SearchCollection.java:378) - ============ Initializing Searcher ============
# 2022-03-06 12:31:35,514 INFO  [main] search.SearchCollection (SearchCollection.java:379) - Index: indexes/msmarco-passage/lucene-index-msmarco-expanded-topk10
# 2022-03-06 12:31:35,771 INFO  [main] search.SearchCollection (SearchCollection.java:459) - Language: en
# 2022-03-06 12:31:35,771 INFO  [main] search.SearchCollection (SearchCollection.java:460) - Stemmer: porter
# 2022-03-06 12:31:35,772 INFO  [main] search.SearchCollection (SearchCollection.java:461) - Keep stopwords? false
# 2022-03-06 12:31:35,772 INFO  [main] search.SearchCollection (SearchCollection.java:462) - Stopwords file: null
# 2022-03-06 12:31:35,773 INFO  [main] search.SearchCollection (SearchCollection.java:463) - Number of threads for running different parameter configurations: 1
# ...

# %%
# MRR at rank 10 for all 500 developer queries (using original msmarco_passage_eval file)
# !python tools/scripts/msmarco/msmarco_passage_eval.py \
 collections/msmarco-passage/qrels.dev.tsv runs/run.msmarco-passage.bm25-default+d2q+rm3.topics.msmarco-passage.dev.500.tsv
# Out:
# Queries Ranked: 500
# #####################
# MRR @10: 0.18454047619047628
# QueriesRanked: 500
# #####################
# 0

# %%
# RR at rank 100 for each 500 developer queries (using our modified msmarco_passage_eval_modified file)
# !python tools/scripts/msmarco/msmarco_passage_eval_modified.py \
 collections/msmarco-passage/qrels.dev.tsv runs/run.msmarco-passage.bm25-default+d2q+rm3.topics.msmarco-passage.dev.500.tsv
# Out:
# 2 0.07142857142857142
# 52 0.25
# 58 0.011363636363636364
# 184 0
# 222 0
# 254 0.3333333333333333
# 255 0
# 362 0
# 370 0
# 409 0
# 484 0
# 514 0.014492753623188406
# 579 0.5
# 697 0.1111111111111111
# 846 0
# 943 0.06666666666666667
# 1007 0.08333333333333333
# 1099 1.0
# 1137 0.02040816326530612
# 1157 0.03225806451612903
# 1195 0.01020408163265306
# 1231 0.01639344262295082
# 1288 0.1111111111111111
# 1289 0.5
# 1424 0
# 1550 0
# 1576 0
# 1579 0.03571428571428571
# 1697 0
# 1724 0
# 1819 0.1111111111111111
# 1956 0
# 1993 0
# 2057 0
# 2123 0.017857142857142856
# 8756 0
# 43677 0.1
# 43722 0
# 43873 1.0
# 43958 0.09090909090909091
# 43994 0.125
# 47140 0.014705882352941176
# 61161 0.058823529411764705
# 87396 0.011494252873563218
# 131137 0.03225806451612903
# 226995 0.013513513513513514
# 262156 1.0
# 262207 0.05263157894736842
# 262230 1.0
# 262232 0
# 262274 0
# 262302 0
# 262330 0.16666666666666666
# 262356 0.0196078431372549
# 262365 0.5
# 262392 0.3333333333333333
# ...
